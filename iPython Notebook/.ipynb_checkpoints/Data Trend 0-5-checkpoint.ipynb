# %% [markdown]
# ## Some Trends

# %% [markdown]
# ### 1. Number of Crimes by Year

# %% [markdown]
# Code: ***col5_report_year.py*** This code returns number of crimes by year.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
df = pd.read_table('col5_report_year.out',header=-1)
df = df.sort([0], ascending=True)
plt.plot(list(df[0]),list(df[1]),linestyle='--', marker='o')
plt.title("Number of Compliant by Year")
plt.xlabel("Year")
plt.ylabel("Number of Compliant")
plt.show()
# Out:
# /Users/sunevan/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app

# %% [markdown]
# **Trend:** Overall, the crime decreased year over year. Our goal is to identify when, where, and why the crime decreased.

# %% [markdown]
# ### 2. Number of crimes by year and by month

# %% [markdown]
# Code: ***col5_report_year_month.py*** This code returns number of crimes by each year and each month.

# %%
fig = plt.figure(figsize=(10, 8))
df = pd.read_table('col5_report_year_month.out',header=-1)
df = df.sort([0,1], ascending=True)
for i in df[0].unique():
    plt.plot(list(df[df[0]==i][1]),list(df[df[0]==i][2]),linestyle='--', marker='o',label = i)
plt.xticks(list(range(1,13)))
plt.legend(loc="upper left")
plt.title("Number of compliants by year and by month")
plt.show()
# Out:
# /Users/sunevan/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()

# %% [markdown]
# It seems that Jan and Feb in 2015 has some abnormal number of crimes compared to the other month.
#
# I also plot a boxplot and clearly Feburay has the lowest number of crimes on average (partialy is becasue of a shorter month). It seems there is an outliar in May and December.

# %%
fig = plt.figure(figsize=(10, 8))
month = list()
for i in (list(range(1,13))):
    month.append(df[df[1]==i][2])

plt.boxplot(month)
plt.title("Box Plot by Month")
plt.show()

# %% [markdown]
# ### 3. Number of crimes by year and by week

# %% [markdown]
# Code: ***col5_report_year_week.py*** This code provides number of crimes by year and by week.

# %%
fig = plt.figure(figsize=(15, 15))
df = pd.read_table('col5_report_year_week.out',header=-1)
df = df.sort([0,1], ascending=True)
for i in df[0].unique():
    plt.plot(list(df[df[0]==i][1]),list(df[df[0]==i][2]),linestyle='--', marker='o',label = i)
plt.legend(loc="upper left")
plt.xticks(list(df[1].unique()))
plt.show()
# Out:
# /Users/sunevan/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()

# %% [markdown]
# After plotting by week, it is clear that the week 44 in 2012 has an abnormal trend. It is probably because of hurricane sandy happened during that period.

# %% [markdown]
# ### 4. Number of crimes by day of week

# %% [markdown]
# Code: ***col5_report_year_week_day.py*** This code provides number of crimes by year and weeknum in each day of the week.

# %%
fig = plt.figure(figsize=(12, 10))
df = pd.read_table('col5_report_year_week_day.out',header=-1)
df = df.sort([0,1], ascending=True)
dow = list()
for i in (list(range(1,8))):
    dow.append(df[df[2]==i][3])
plt.boxplot(dow)
plt.show()
# Out:
# /Users/sunevan/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()

# %% [markdown]
# By looking at the boxplot, Tue-Fri is the peak and weekend has less compliants. Also, weekdays have more outliars.

# %% [markdown]
# ### 5. Number of compliants by hour

# %% [markdown]
# Code: ***col1_2_hour.py***. This code is to check number of crimes by hour.

# %%
fig = plt.figure(figsize=(12, 10))
df = pd.read_table('col1_2_hour.out',header=-1)
df = df.sort([0,1,2,3], ascending=True)
dow = list()
for i in (list(range(0,24))):
    dow.append(df[df[3]==i][4])
plt.boxplot(dow)
plt.xticks(list(range(1,25)),list(range(0,24)))
plt.show()
# Out:
# /Users/sunevan/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()

# %% [markdown]
# Number of crimes is gradually increasing after 7 am and then start decreasing after midnight. However, there are some very high abnormal outliars happened between 12 - 1 am.

# %%
dfzero = df[df[3]==0]
dfoutliar = dfzero[dfzero[4]>300]
dfoutliar
# Out:
#           0   1  2  3    4
# 17430  2006  52  7  0  506
# 17454  2007   1  1  0  596
# 26214  2008   1  2  0  529
# 34926  2009   1  4  0  373
# 52374  2010  53  5  0  475
# 61134  2011  52  6  0  558
# 69894  2012  52  7  0  442
# 69942  2013   1  2  0  401
# 78702  2014   1  3  0  458
# 87390  2015   1  4  0  313

# %% [markdown]
# The outliars are usually between 12 and 1 am on the new year. It makes sense since the NYE celebrations.

# %% [markdown]
# ### 6. Number of crimes by length of compliant

# %% [markdown]
# Code: ***length_of_compliant.py***. The code provides number of crimes by the length of complaint. When the crime has no to_date and to_time, the length will be counted as **0**.

# %%
fig = plt.figure(figsize=(12, 10))
df = pd.read_table('col1_2_3_4_length_of_compliant.out',header=-1)
df = df.sort([0], ascending=True)

plt.plot(list(df[0]),list(df[1]),linestyle='-')
plt.title("Number of compliant by length of compliant (Log-Log)")
plt.xlabel("Length of compliant")
plt.ylabel("Number of Compliant")
plt.xscale('log')
plt.yscale('log')
plt.show()
# Out:
# /Users/sunevan/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()

# %% [markdown]
# Overall,number of crimes decays over the length of the compliant after transforming to log-log.

# %% [markdown]
# ### 7. Number of compliants by year and by crime type

# %% [markdown]
# Code: ***col5_6_report_kycd.py***. The code provides number of crimes by year and by KY_CD, which stands for the crime type.

# %%
fig = plt.figure(figsize=(15, 10))
df = pd.read_table('col5_6_report_year_kycd.out',header=-1)
df.columns = ["year","kycd","count"]
#find the top 10 KY_CD
top_kycd = df.groupby(["kycd"], as_index=False).sum().sort(["count"], ascending=False)[0:10]["kycd"]
df = df.sort(["year"],ascending=True)
for i in list(top_kycd):
    plt.plot(list(df[df["kycd"]==i]["year"]),list(df[df["kycd"]==i]["count"]),linestyle='--', marker='o',label = i)
plt.legend(loc="upper left")
plt.xticks(list(df["year"].unique()))
plt.ylabel("Number of crime per year")
plt.show()
# Out:
# /Users/sunevan/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:5: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /Users/sunevan/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:6: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %% [markdown]
# From the list, the crime 341 is the most popluar and did not decrease over the year. It seems that crime 235 and 361 may contribute the year over year decrease as the trend continued going down after 2012.

# %% [markdown]
# ### 8. Number of compliants by year and by borough

# %% [markdown]
# Code: ***col5_13_report_year_borough.py***. The code provides number of crime by number of compliants, year, and borough.

# %%
fig = plt.figure(figsize=(15,5))
df = pd.read_table('col5_13_report_year_borough.out',header=-1)
df = df.sort([0,1], ascending=True)
for i in df[1].unique():
    plt.plot(list(df[df[1]==i][0]),list(df[df[1]==i][2]),linestyle='--', marker='o',label = i)
plt.legend(loc="upper left")
plt.xticks(list(df[0].unique()))
plt.show()



for i in df[1].unique():
    fig = plt.figure(figsize=(10,4))
    plt.plot(list(df[df[1]==i][0]),list(df[df[1]==i][2]),linestyle='--', marker='o',label = i)
    plt.legend(loc="upper left")
    plt.xticks(list(df[0].unique()))
    plt.show()
# Out:
# /Users/sunevan/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()

# %% [markdown]
# Looking at the stacked the line chart, the decreasing trend is not very clear. After plotting the trend borough by borough, it is more clear that broklyn contributes the most to the decrease, followed by manhattan.

# %% [markdown]
# ### 9. Collision data vs compliant data

# %%
motor = pd.read_table('/Users/sunevan/Dropbox/Spring 2017/Big Data/ds1004project/part 2/NYPD_Motor_Vehicle_Collisions.out',header=-1)

motor.columns = ["year","month","weeknum",'weekday',"freq"]

crime = pd.read_table('/Users/sunevan/Dropbox/Spring 2017/Big Data/ds1004project/part 2/col5_summary_time.out',header=-1)

crime.columns = ["year","month","weeknum",'weekday',"freq"]

combined_df = pd.merge(crime, motor, on=["year","month","weeknum","weekday"], how='left')

# %%
combined_df.columns = ["year","month","weeknum",'weekday',"freq_complian","freq_motor"]
combined_df.to_csv("date collison and compliant.csv")

# %%
combine_df = combined_df[combined_df['freq_motor'].notnull()]

# %%
#combine_df['year'] = combine_df['year'].astype(str)
combine_df['month'] = combine_df['month'].astype(str)
#combine_df['weeknum'] = combine_df['weeknum'].astype(str)
combine_df['weekday'] = combine_df['weekday'].astype(str)
combine_df.dtypes
# Out:
# /Users/sunevan/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/sunevan/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# year               int64
# month             object
# weeknum            int64
# weekday           object
# freq_complian      int64
# freq_motor       float64
# dtype: object

# %%
import numpy
numpy.corrcoef(combine_df["freq_complian"], combine_df["freq_motor"])[0, 1]
# Out:
# 0.40952282745252239

# %%
combine_df.head()
# Out:
#     year month  weeknum weekday  freq_complian  freq_motor
# 4   2012    10       42       4           1543       630.0
# 5   2013     6       26       5           1473       608.0
# 9   2012    11       45       4           1048       550.0
# 13  2013    12       50       3           1360       605.0
# 19  2014    11       48       5           1166       444.0

# %%
grouped = combine_df.groupby(["year","weeknum"],sort=True).sum()

# %%
numpy.corrcoef(grouped["freq_complian"], grouped["freq_motor"])[0, 1]
# Out:
# 0.74382199865382681

# %%
fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(111)
ax1.plot(list(grouped["freq_complian"]),color = "red")
#ax1.set_xticks(list(grouped.index))
ax1.set_ylabel("Total Number of Crimes")


ax2 = ax1.twinx()
ax2.plot(list(grouped["freq_motor"]),color = "blue")
#ax2.set_xticks(list(grouped.index))
ax2.set_ylabel("Total Number of Collisions")
plt.show()

# %%
len(list(grouped.index))
# Out:
# 185

# %%
grouped
# Out:
#               freq_complian  freq_motor
# year weeknum
# 2012 1                 1099       482.0
#      26                1283       538.0
#      27                9984      3843.0
#      28               10595      3832.0
#      29               10138      3886.0
#      30               10237      3820.0
#      31               10281      3928.0
#      32               10665      3878.0
#      33               10237      3820.0
#      34               10466      3579.0
#      35                9921      3939.0
#      36                9810      3895.0
#      37               10053      4063.0
#      38               10117      3823.0
#      39               10038      3815.0
#      40               10212      3877.0
#      41                9712      3900.0
#      42               10149      4205.0
#      43                9713      3660.0
#      44                6025      2654.0
#      45                7577      3919.0
#      46                8972      4102.0
# ...

# %% [markdown]
# ### 10

# %%
zipcode = pd.read_table('/Users/sunevan/Dropbox/Spring 2017/Big Data/ds1004project/part 2/col5_compared_to_zipcode.out',header=-1)

zipcode.columns = ["zipcode","year","month",'weeknum',"weekday","freq"]
#zipcode["zipcode"] =  zipcode["zipcode"]
zipcode["month"] =  zipcode["month"].astype(str)
zipcode["year"] =  zipcode["year"].astype(str)
zipcode["weeknum"] =  zipcode["weeknum"].astype(str)
zipcode["weekday"] =  zipcode["weekday"].astype(str)

zip_grouped = zipcode.groupby(["zipcode"],sort=True).sum()

# %%
zip_grouped
# Out:
#           freq
# zipcode
# 83.0      4834
# 10001.0  75590
# 10002.0  52297
# 10003.0  54137
# 10004.0   4323
# 10005.0   3014
# 10006.0   3276
# 10007.0  14333
# 10009.0  31121
# 10010.0  19039
# 10011.0  45297
# 10012.0  29317
# 10013.0  31249
# 10014.0  27344
# 10016.0  26443
# 10017.0  15562
# 10018.0  28077
# 10019.0  42245
# 10020.0   3395
# 10021.0  10045
# 10022.0  24736
# 10023.0  28070
# 10024.0  22236
# 10025.0  44356
# 10026.0  30497
# 10027.0  64166
# 10028.0  14549
# 10029.0  71511
# 10030.0  26366
# 10031.0  44989
# ...        ...
# 11385.0  49528
# 11411.0   7216
# 11412.0  17658
# 11413.0  19109
# 11414.0   9210
# 11415.0   5645
# 11416.0  11924
# 11417.0  15261
# 11418.0  18640
# 11419.0  23118
# 11420.0  21795
# 11421.0  15110
# 11422.0  11370
# 11423.0  12412
# 11426.0   5586
# 11427.0   7090
# 11428.0   6155
# 11429.0  11549
# 11430.0   1546
# 11432.0  36522
# 11433.0  31631
# 11434.0  36639
# 11435.0  27058
# 11436.0  11475
# 11451.0     26
# 11691.0  35276
# ...

# %%
house = pd.read_csv('/Users/sunevan/Dropbox/Spring 2017/Big Data/ds1004project/part 2/Zip_Zhvi_AllHomes.csv')

# %%
ny_house = house[house["Metro"]=="New York"]
ny_house_time = ny_house[ny_house.columns[124:-15]]

nyc_house = pd.DataFrame(
    {'zipcode': ny_house["RegionName"],
     'avg_price': ny_house_time.mean(axis =1)
    })

# %%
zip_code_list = list()
for i in zip_grouped.index:
    zip_code_list.append(int(i))
zip_grouped["zipcode"] = zip_code_list

# %%
zip_and_price = pd.merge(zip_grouped, nyc_house, on='zipcode', how='left')

# %%
zip_and_price = zip_and_price.dropna(axis=0, how='any')
zip_and_price.to_csv("zipcode and price.csv")

# %%
fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(111)
ax1.plot(list(zip_and_price["freq"]),color = "red")
#ax1.set_xticks(list(grouped.index))
ax1.set_ylabel("Total Number of Crimes")


ax2 = ax1.twinx()
ax2.plot(list(zip_and_price["avg_price"]),color = "blue")
#ax2.set_xticks(list(grouped.index))
ax2.set_ylabel("Avg Price")
plt.show()

# %%
numpy.corrcoef(zip_and_price["avg_price"], zip_and_price["freq"])[1,0]
# Out:
# -0.13576309486025692

# %% [markdown]
# ### Compared to Employment

# %%
unemployment = pd.read_csv("/Users/sunevan/Dropbox/Spring 2017/Big Data/ds1004project/useful data/NYC Unemployment  rate.csv")
unemployment.head()
unemployment_key  =list()

#for i in range(unemployment.shape[0]):
look_up = {'Jan': '01', 'Feb': '02', 'Mar': '03', 'Apr': '04', 'May': '05','Dec':'12',
            'Jun': '06', 'Jul': '07', 'Aug': '08', 'Sep': '09', 'Oct': '10', 'Nov': '11'}

unemployment['Month'] = unemployment['Month'].apply(lambda x: look_up[x])    

#unemployment['key'] = unemployment[['Year','Month']].apply(lambda x: ''.join(x), axis=1) 
unemployment["Key"]= unemployment["Year"].astype(str)+' '+unemployment["Month"]

# %%
unemployment.index=unemployment["Key"]

# %%
crime.head()
look_up = {'1': '01', '2': '02', '3': '03', '4': '04', '5': '05','12':'12',
            '6': '06', '7': '07', '8': '08', '9': '09', '10': '10', '11': '11'}

crime['Month'] = crime['month'].astype(str).apply(lambda x: look_up[x])

# %%
crime["Key"]= crime["year"].astype(str)+' '+crime["Month"]

# %%
crime_n = crime.groupby(["Key"],sort=True).sum()

# %%
crime_n["Key"] = list(crime_n.index)

# %%
m = pd.merge(crime_n, unemployment, on = "Key",how='left')
m
m.to_csv("unemployment and crime.csv")
# Out:
#       year  month  weeknum  weekday   freq      Key  Year Month     Label  \
# 0    62186     31      132      122  45351  2006 01  2006    01  2006 Jan
# 1    56168     56      190      112  38308  2006 02  2006    02  2006 Feb
# 2    62186     93      341      124  45529  2006 03  2006    03  2006 Mar
# 3    60180    120      460      125  43621  2006 04  2006    04  2006 Apr
# 4    62186    155      612      118  47106  2006 05  2006    05  2006 May
# 5    60180    180      722      121  46199  2006 06  2006    06  2006 Jun
# 6    62186    217      881      126  47088  2006 07  2006    07  2006 Jul
# 7    62186    248     1019      121  47729  2006 08  2006    08  2006 Aug
# 8    60180    270     1116      123  45606  2006 09  2006    09  2006 Sep
# 9    62186    310     1289      122  46919  2006 10  2006    10  2006 Oct
# 10   60180    330     1378      119  43818  2006 11  2006    11  2006 Nov
# 11   62186    372     1558      130  42703  2006 12  2006    12  2006 Dec
# ...

# %%
fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(111)
ax1.plot(list(m["""Unemployment Rate (%)"""]),color = "red")
ax1.set_xticks(list(m.index))
ax1.set_ylabel("Unemployment Rate")


ax2 = ax1.twinx()
ax2.plot(list(m["freq"]),color = "blue")
ax2.set_xticks(list(m.index))
ax2.set_ylabel("Number of Crimes")
plt.show()

# %%
numpy.corrcoef(m["freq"], m["Unemployment Rate (%)"])[1,0]
# -0.23303916
